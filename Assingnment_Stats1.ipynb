# %% [markdown]
# ***1. What is a random variable in probability theory?***
#
# A random variable is a numerical representation of the outcomes of a random experiment. It assigns a numerical value to each possible event in a sample space.
#
# For example:
#
# Tossing a coin: Let
# 𝑋
# X be the random variable where
# 𝑋
# =
# 1
# X=1 for heads and
# 𝑋
# =
# 0
# X=0 for tails.
# Rolling a die: Let
# 𝑋
# X be the random variable representing the number rolled (1 to 6).
# Random variables help in quantifying uncertainty in probability theory.

# %% [markdown]
# ***2. What are the types of random variables?***
#
# **There are two types of random variables:**
#
# Discrete Random Variable:
# Takes countable values (finite or infinite).
# Example: Number of heads in 10 coin flips.
#
# Continuous Random Variable:
# Takes an infinite number of values within a range.
# Example: The height of people, temperature, or time taken to complete a task.

# %% [markdown]
# ***3. What is the difference between discrete and continuous distributions?***
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***4. What are probability distribution functions (PDF)?***
#
# A Probability Distribution Function (PDF) describes the likelihood of a random variable taking specific values.
#
# For Discrete Variables: The Probability Mass Function (PMF) is used, which gives the probability of exact values. Example:
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# P(X=x)
# For Continuous Variables: The Probability Density Function (PDF) is used, where the probability of a specific value is 0, and probability is given by the area under the curve in a range. Example:
#
# 𝑃
# (
# 𝑎
# ≤
# 𝑋
# ≤
# 𝑏
# )
# =
# ∫
# 𝑎
# 𝑏
# 𝑓
# (
# 𝑥
# )
# 𝑑
# 𝑥
# P(a≤X≤b)=∫
# a
# b
# ​
#  f(x)dx

# %% [markdown]
# ***5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?***
#
# A Cumulative Distribution Function (CDF) gives the probability that a random variable
# 𝑋
# X is less than or equal to a certain value:
#
# 𝐹
# (
# 𝑥
# )
# =
# 𝑃
# (
# 𝑋
# ≤
# 𝑥
# )
# F(x)=P(X≤x)
# PDF (or PMF) gives probability density or mass at a point.
# CDF gives accumulated probability up to a certain point.
# For example, if rolling a die:
#
# 𝐹
# (
# 3
# )
# =
# 𝑃
# (
# 𝑋
# ≤
# 3
# )
# =
# 𝑃
# (
# 1
# )
# +
# 𝑃
# (
# 2
# )
# +
# 𝑃
# (
# 3
# )
# F(3)=P(X≤3)=P(1)+P(2)+P(3)

# %% [markdown]
# ***6. What is a discrete uniform distribution?***
#
# A discrete uniform distribution is one where all outcomes have equal probability.
#
# Example: Rolling a fair die (1-6), each outcome has a probability of
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 1
# 6
# ,
# 𝑥
# ∈
# {
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# ,
# 5
# ,
# 6
# }
# P(X=x)=
# 6
# 1
# ​
#  ,x∈{1,2,3,4,5,6}

# %% [markdown]
# ***7. What are the key properties of a Bernoulli distribution?***
#
# A Bernoulli distribution models a single trial with two possible outcomes: success (
# 1
# 1) or failure (
# 0
# 0).
#
# Properties:
#
# Probability of success:
# 𝑃
# (
# 𝑋
# =
# 1
# )
# =
# 𝑝
# P(X=1)=p
#
# Probability of failure:
# 𝑃
# (
# 𝑋
# =
# 0
# )
# =
# 1
# −
# 𝑝
# P(X=0)=1−p
#
# Mean:
# 𝐸
# (
# 𝑋
# )
# =
# 𝑝
# E(X)=p
#
# Variance:
# 𝑉
# 𝑎
# 𝑟
# (
# 𝑋
# )
# =
# 𝑝
# (
# 1
# −
# 𝑝
# )
#
# Var(X)=p(1−p)
# Example:
#
#  Tossing a coin with
# 𝑝
# =
# 0.5
# p=0.5.

# %% [markdown]
# ***8. What is the binomial distribution, and how is it used in probability?***
#
# A binomial distribution represents the number of successes in
# 𝑛
# n independent Bernoulli trials.
#
# Formula:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# where:
#
# 𝑛
# n = total trials
#
# 𝑘
# k = number of successes
#
# 𝑝
# p = probability of success
#
# Example:
#
# Flipping a coin 10 times, probability of getting exactly 6 heads.

# %% [markdown]
# ***9. What is the Poisson distribution and where is it applied?***
#
# A Poisson distribution models the probability of a number of events occurring in a fixed interval, given a constant rate.
#
# Formula:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝑒
# −
# 𝜆
# 𝜆
# 𝑘
# 𝑘
# !
# P(X=k)=
# k!
# e
# −λ
#  λ
# k
#
#
#
# where
# 𝜆
# λ is the average number of events per interval.
#
# Applications:
#
# Number of customer arrivals at a store per hour.
# Number of emails received per minute.

# %% [markdown]
# ***10. What is a continuous uniform distribution?***
#
# A continuous uniform distribution has equal probability over a given range
#
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b].
#
# PDF:
#
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 𝑏
# −
# 𝑎
# ,
# 𝑎
# ≤
# 𝑥
# ≤
# 𝑏
# f(x)=
# b−a
# 1
# ​
#  ,a≤x≤b
#
#
# Example:
#
#  A random time between 0 and 10 minutes has a uniform probability.

# %% [markdown]
# ***11. What are the characteristics of a normal distribution?***
#
# Bell-shaped & Symmetric
#
# Defined by Mean
# 𝜇
# μ and Standard Deviation
# 𝜎
#
# σ
# Total area under curve = 1
#
# Empirical Rule:
#
# 68% of values within
# 𝜇
# ±
# 𝜎
# μ±σ
# 95% within
# 𝜇
# ±
# 2
# 𝜎
# μ±2σ
# 99.7% within
# 𝜇
# ±
# 3
# 𝜎
# μ±3σ

# %% [markdown]
# ***12. What is the standard normal distribution, and why is it important?***
#
# A standard normal distribution is a normal distribution with:
#
# Mean
# 𝜇
# =
# 0
#
#
# Standard deviation
# 𝜎
# =
# 1
#
#
# It is important because it allows us to use Z-scores for probability calculations.

# %% [markdown]
# ***13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?***
#
# CLT states that for a large enough sample size, the sample mean follows a normal distribution regardless of the population’s original distribution.
#
# Importance:
#
# Allows us to use normal distribution for inference.
#
# Justifies using Z-tests and confidence intervals.

# %% [markdown]
# ***14. How does the Central Limit Theorem relate to the normal distribution?***
#
# CLT ensures that as sample size increases, the distribution of sample means approaches a normal distribution.

# %% [markdown]
# ***15. What is the application of Z statistics in hypothesis testing?***
#
# Z-tests determine if a sample mean significantly differs from a population mean.
#
# Used when:
#
# Sample size is large (
# 𝑛
# ≥
# 30
# n≥30)
#
# Population standard deviation is known

# %% [markdown]
# ***16. How do you calculate a Z-score, and what does it represent?***
#
# 𝑍
# =
# 𝑥
# −
# 𝜇
# 𝜎
# Z=
# σ
# x−μ
# ​
#
# It measures how many standard deviations a value
# 𝑥
# x is from the mean.

# %% [markdown]
# ***17. What are point estimates and interval estimates in statistics?***
#
# Point Estimate: A single value estimate (e.g., sample mean).
#
# Interval Estimate: A range, like confidence intervals.

# %% [markdown]
# ***18. What is the significance of confidence intervals in statistical analysis?***
#
# They provide a range of values likely to contain the population parameter with a certain probability.

# %% [markdown]
# ***Practicle QUE***

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Generate a random variable and display its value
random_value = np.random.rand()
print("Random Variable:", random_value)

# 2. Generate a discrete uniform distribution and plot PMF
values = np.arange(1, 7)
probabilities = np.ones(6) / 6
plt.bar(values, probabilities, alpha=0.6, color='b', edgecolor='k')
plt.xlabel('Values')
plt.ylabel('Probability')
plt.title('PMF of a Discrete Uniform Distribution')
plt.show()

# 3. Bernoulli distribution PDF
def bernoulli_pdf(p, x):
    return p**x * (1 - p)**(1 - x)

print("Bernoulli PDF (p=0.5, x=1):", bernoulli_pdf(0.5, 1))

# 4. Simulate binomial distribution (n=10, p=0.5) and plot histogram
binomial_samples = np.random.binomial(n=10, p=0.5, size=1000)
sns.histplot(binomial_samples, bins=11, kde=False, stat="density", color='g')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.title('Histogram of Binomial Distribution (n=10, p=0.5)')
plt.show()

# 5. Create Poisson distribution and visualize it
poisson_samples = np.random.poisson(lam=5, size=1000)
sns.histplot(poisson_samples, bins=15, kde=False, color='r')
plt.xlabel('Occurrences')
plt.ylabel('Frequency')
plt.title('Poisson Distribution Histogram')
plt.show()

# 6. Calculate and plot CDF of a discrete uniform distribution
cdf = np.cumsum(probabilities)
plt.step(values, cdf, where='mid', color='b', label='CDF')
plt.xlabel('Values')
plt.ylabel('Cumulative Probability')
plt.title('CDF of a Discrete Uniform Distribution')
plt.legend()
plt.show()

# 7. Generate continuous uniform distribution and visualize
continuous_samples = np.random.uniform(0, 10, 1000)
sns.histplot(continuous_samples, bins=20, kde=True, color='purple')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Continuous Uniform Distribution')
plt.show()

# 8. Simulate normal distribution data and plot histogram
normal_samples = np.random.normal(loc=0, scale=1, size=1000)
sns.histplot(normal_samples, bins=30, kde=True, color='orange')
plt.title('Histogram of Normal Distribution')
plt.show()

# 9. Calculate Z-scores and plot
z_scores = (normal_samples - np.mean(normal_samples)) / np.std(normal_samples)
sns.histplot(z_scores, bins=30, kde=True, color='cyan')
plt.title('Z-Scores Distribution')
plt.show()

# 10. Implement CLT using Python
def central_limit_theorem():
    samples = [np.mean(np.random.exponential(scale=2, size=30)) for _ in range(1000)]
    sns.histplot(samples, bins=30, kde=True)
    plt.title('Central Limit Theorem Applied to Exponential Distribution')
    plt.show()

central_limit_theorem()

# More functions for additional tasks can be added similarly.
# Out:
# Random Variable: 0.14430741411441994
# Bernoulli PDF (p=0.5, x=1): 0.5
